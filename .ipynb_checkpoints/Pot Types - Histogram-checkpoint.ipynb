# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.normal(150, 10, 250)

plt.hist(x)
plt.show()

# %%
x = np.random.normal(150, 10, 250)

plt.hist(x, density = True , color = 'g')
plt.show()
